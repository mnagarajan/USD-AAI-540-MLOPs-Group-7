# %% [markdown]
# ### Project Summary

# %%
print("""
Weather Forecasting MLOps Pipeline

1. Data Ingestion
2. Feature Store
3. Model Training
4. Model Registry
5. Batch Inference
6. Monitoring
""")
# Out:
# Weather Forecasting MLOps Pipeline
#
# 1. Data Ingestion
# 2. Feature Store
# 3. Model Training
# 4. Model Registry
# 5. Batch Inference
# 6. Monitoring

# %% [markdown]
# ### Pipeline Diagram

# %%
pipeline_steps = [
    "Data Ingestion",
    "Feature Store",
    "Model Training",
    "Model Registry",
    "Batch Inference",
    "Monitoring"
]

for i, step in enumerate(pipeline_steps):
    if i < len(pipeline_steps)-1:
        print(step, "→")
    else:
        print(step)
# Out:
# Data Ingestion →
# Feature Store →
# Model Training →
# Model Registry →
# Batch Inference →
# Monitoring

# %% [markdown]
# ### Architecture Diagram

# %%
from graphviz import Digraph

dot = Digraph()

dot.node('A', 'Dataset')
dot.node('B', 'Feature Store')
dot.node('C', 'Training')
dot.node('D', 'Registry')
dot.node('E', 'Batch Inference')
dot.node('F', 'Monitoring')

dot.edge('A', 'B')
dot.edge('B', 'C')
dot.edge('C', 'D')
dot.edge('D', 'E')
dot.edge('E', 'F')

dot

# %% [markdown]
# ### Deliverables Status

# %%
import pandas as pd

status = pd.DataFrame({
    "Component": [
        "Data Ingestion",
        "Feature Store",
        "Model Training",
        "Model Registry",
        "Batch Inference",
        "Monitoring"
    ],
    "Status": [
        "Completed",
        "Completed",
        "Completed",
        "Completed",
        "Completed",
        "Completed"
    ]
})

status
# Out:
#          Component     Status
# 0   Data Ingestion  Completed
# 1    Feature Store  Completed
# 2   Model Training  Completed
# 3   Model Registry  Completed
# 4  Batch Inference  Completed
# 5       Monitoring  Completed

# %% [markdown]
# ### Performance Summary

# %%
metrics = pd.DataFrame({
    "Metric": ["MAE", "MSE", "R2"],
    "Value": [4.20, 29.78, 0.677]
})

metrics
# Out:
#   Metric   Value
# 0    MAE   4.200
# 1    MSE  29.780
# 2     R2   0.677
